# %%
pip install spotipy --upgrade
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id='515f38c0a1a2478aae336e00088ff6b2',
    client_secret='711ecbc8420f4dd78868e491afc58da5',
))

# %%
results = sp.search(q='artist:Pixies', type='artist')
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache

# %%
results['artists']['items'][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/6zvul52xwTWzilBZl6BUbT'},
#  'followers': {'href': None, 'total': 3143348},
#  'genres': ['alternative rock', 'boston rock', 'permanent wave', 'rock'],
#  'href': 'https://api.spotify.com/v1/artists/6zvul52xwTWzilBZl6BUbT',
#  'id': '6zvul52xwTWzilBZl6BUbT',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb6281c5914a991e5c0e6e9d13',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab676161000051746281c5914a991e5c0e6e9d13',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f1786281c5914a991e5c0e6e9d13',
#    'width': 160}],
#  'name': 'Pixies',
#  'popularity': 72,
#  'type': 'artist',
#  'uri': 'spotify:artist:6zvul52xwTWzilBZl6BUbT'}

# %%
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy

# %%
lz_uri = 'spotify:artist:36QJpDe2go2KgaRleHCDTp'

# %%
client_credentials_manager = SpotifyClientCredentials(client_id='515f38c0a1a2478aae336e00088ff6b2',client_secret='711ecbc8420f4dd78868e491afc58da5')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
results = sp.artist_top_tracks(lz_uri)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# track    : Stairway to Heaven - Remaster
# audio    : https://p.scdn.co/mp3-preview/337c8d45ac66899bc2db9ef3ed9438fe1d035ab1?cid=515f38c0a1a2478aae336e00088ff6b2
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
# track    : Immigrant Song - Remaster
# audio    : https://p.scdn.co/mp3-preview/f50f3416ea0807503e172ba87a92d8047d4f95da?cid=515f38c0a1a2478aae336e00088ff6b2
# cover art: https://i.scdn.co/image/ab67616d0000b27390a50cfe99a4c19ff3cbfbdb
# track    : Whole Lotta Love - 1990 Remaster
# audio    : https://p.scdn.co/mp3-preview/89f3dc45265602fa874c23d638538af0f2c6b56a?cid=515f38c0a1a2478aae336e00088ff6b2
# cover art: https://i.scdn.co/image/ab67616d0000b273fc4f17340773c6c3579fea0d
# track    : Black Dog - Remaster
# audio    : https://p.scdn.co/mp3-preview/78dd352fdbe8d2a867b72c5a71ac44ef6a462ab4?cid=515f38c0a1a2478aae336e00088ff6b2
# ...

# %%
results = sp.artist_top_tracks('spotify:artist:6zvul52xwTWzilBZl6BUbT')

for track in results['tracks'][:10]:
    print(track['name'])
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Where Is My Mind? - 2007 Remaster
# Here Comes Your Man
# All I Think About Now
# Hey
# Monkey Gone to Heaven
# The Thing
# Debaser
# Gouge Away
# Wave Of Mutilation
# Que Sera Sera

# %%
# 1. What are the ten most popular songs on the playlist?

import spotipy

urn = 'spotify:playlist:7r2XnAUl6moWkcwOaWgihD'
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id='515f38c0a1a2478aae336e00088ff6b2',
    client_secret='711ecbc8420f4dd78868e491afc58da5',
))

playlist = sp.playlist(urn)
print(playlist)

user = sp.user('plamere')
print(user)
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# ...

# %%
print(user.keys)
# Out:
# <built-in method keys of dict object at 0x10809b300>

# %%
pprint(user)
# Out:
# Pretty printing has been turned OFF

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

lz_uri = 'spotify:playlist:7r2XnAUl6moWkcwOaWgihD'

spotify = spotipy.Spotify(client_credentials_manager=(client_id='515f38c0a1a2478aae336e00088ff6b2', client_secret='711ecbc8420f4dd78868e491afc58da5')
results = spotify.playlist_top_tracks(lz_uri)


results = spotify.playlist_top_tracks(lz_uri)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
#   Cell In[51], line 6
#     spotify = spotipy.Spotify(client_credentials_manager=(client_id=='515f38c0a1a2478aae336e00088ff6b2', client_secret='711ecbc8420f4dd78868e491afc58da5')
#                                                                                                          ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
#NOTE I used "Here’s another example showing how to get 30 second samples and cover art for the top 10 tracks for Led Zeppelin" as an example
#https://spotipy.readthedocs.io/en/2.24.0/

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id='515f38c0a1a2478aae336e00088ff6b2', client_secret='711ecbc8420f4dd78868e491afc58da5')
spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

lz_uri = 'spotify:playlist:7r2XnAUl6moWkcwOaWgihD'
results = spotify.playlist_tracks(lz_uri)

# Display the top 10 tracks
for track in results['items'][:10]:
    track_info = track['track']  
    print('track    : ' + track_info['name'])
    print()
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# track    : Waiting For October
#
# track    : Scott Pilgrim
#
# track    : Ginger
#
# track    : Frontwards
#
# track    : First Revival
#
# track    : I Can See It (But I Can't Feel It)
#
# track    : Skyscraper
#
# track    : Jar Of Cardinals
#
# track    : Get Back
#
# track    : Tripoli

# %%
#2 What percentage of them have a popularity of zero? Print them out, sorted by the band name.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 3
#       1 #2 What percentage of them have a popularity of zero? Print them out, sorted by the band name.
# ----> 3 print(playlist_cover_image('7r2XnAUl6moWkcwOaWgihD'))
#
# NameError: name 'playlist_cover_image' is not defined
