# %% [markdown]
# # Texas Cosmetologist Violations
#
# Texas has a system for [searching for license violations](https://www.tdlr.texas.gov/cimsfo/fosearch.asp). You're going to search for cosmetologists!
#
# > You can use the classwork notebook and also [my Everything scraping reference](https://jonathansoma.com/everything/scraping)
#
# I shouldn't have to say this, but **do not use ChatGPT for this assignment.**

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# We'll be using either Playwrightfor this, *not* requests.

# %%
# !pip install playwright
# Out:
# Requirement already satisfied: playwright in /Users/rosakettumaki/.pyenv/versions/3.12.7/lib/python3.12/site-packages (1.48.0)
# Requirement already satisfied: greenlet==3.1.1 in /Users/rosakettumaki/.pyenv/versions/3.12.7/lib/python3.12/site-packages (from playwright) (3.1.1)
# Requirement already satisfied: pyee==12.0.0 in /Users/rosakettumaki/.pyenv/versions/3.12.7/lib/python3.12/site-packages (from playwright) (12.0.0)
# Requirement already satisfied: typing-extensions in /Users/rosakettumaki/.pyenv/versions/3.12.7/lib/python3.12/site-packages (from pyee==12.0.0->playwright) (4.12.2)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !playwright install

# %%
from playwright.async_api import async_playwright

# %%
playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless=False)

# %%
page = await browser.new_page()

# %% [markdown]
# ## Starting your search
#
# Starting from [here](https://www.tdlr.texas.gov/cimsfo/fosearch.asp), search for cosmetologist violations for people with the last name **Nguyen**.

# %%
await page.goto("https://www.tdlr.texas.gov/cimsfo/")
# Out:
# <Response url='https://www.tdlr.texas.gov/cimsfo/' request=<Request url='https://www.tdlr.texas.gov/cimsfo/' method='GET'>>

# %%
await page.get_by_label("Search by Last Name:").select_option('10')
await page.get_by_role("button", name="Search").click()

# %%
import io

# %%
await page.get_by_label("Search by Last Name:").select_option('10')
# Click the button
await page.get_by_role("button", name="Search").click()

# Get the table
html = await page.content()
tables = pd.read_html(io.StringIO(html))
df = tables[2]
df.head()

# %% [markdown]
# #### Scraping
#
# Once you are on the results page, do this. **I step you through things bit by bit, so it's going to be a little different than we did in class.** Also, no `pd.read_html` allowed because this isn't reaaallly tabular data (or there's just too much to clean up).
#
# Once you've loaded the page: **what selector are you going to do use to find the data?** In class we used things like `.article` or `.head-list`.
#
# > You honestly can do this all with Playwright, no BeautifulSoup involved! But we didn't cover that in class so you should stick to this method:
# >
# > ```python
# > html = await page.content()
# > doc = BeautifulSoup(html)
# > ```

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html)
soup

print(soup.prettify())
# Out:
# <html class="supports csstransforms3d" lang="en">
#  <head>
#   <title>
#    Administrative Orders - Search
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <link href="/images/favicon.png" rel="shortcut icon" type="image/x-icon"/>
#   <!-- Google Tag Manager -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-8C39DM76B2&amp;l=dataLayer&amp;cx=c&amp;gtm=45He4bj0v76914737za200" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-MPP5WF5">
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-MPP5WF5');
#   </script>
#   <!-- End Google Tag Manager -->
#   <link href="/css/reset.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/animate.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/main-stylesheet.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/lightbox.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/shortcodes.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/custom-fonts.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/custom-colors.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/responsive.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/dat-menu.css" rel="stylesheet" type="text/css"/>
#   <link href="css/fosearch.css" rel="stylesheet" type="text/css"/>
#   <!--[if lte IE 8]>
# 	<link type="text/css" rel="stylesheet" href="/css/ie-ancient.css" />
# 	<![endif]-->
#   <script src="js/app.js" type="text/javascript">
#   </script>
#  </head>
#  <body class="ot-menu-ipad-enable ot-menu-iphone-enable">
#   <div class="effect-1" id="dat-menu">
#    <div class="dat-menu-container" style='background: url("https://www.tdlr.texas.gov/images/background-1.jpg") 0% 0% / auto repeat scroll padding-box border-box rgba(0, 0, 0, 0);'>
#     <div class="dat-menu-top-header">
#      <a class="dat-menu-menu" href="#dat-menu">
#       <i class="fa fa-bars">
#       </i>
#      </a>
#      <a class="dat-menu-search" href="#">
#       <i class="fa fa-search">
#       </i>
#      </a>
#      <a href="#">
#       <img alt="" src="/images/logo.png" style="background-color: #0589cd;"/>
#      </a>
#      <form action="">
#       <input name="s" type="text" value=""/>
#       <input type="submit" value=""/>
#      </form>
#     </div>
#     <div class="dat-menu-wrapper dat-menu-padding">
#      <!-- Google Tag Manager (noscript) -->
#      <noscript>
#       <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MPP5WF5" style="display:none;visibility:hidden" width="0">
#       </iframe>
#      </noscript>
#      <!-- End Google Tag Manager (noscript) -->
#      <div class="boxed active">
#       <div class="devwrapper">
#        <header class="header willfix">
#         <div class="wrapper">
#          <div class="header-left">
#           <div class="header-logo">
#            <a class="otanimation" data-anim-in="flipOutX" data-anim-object=".header-logo a.otanimation img, .header-logo a.otanimation h1" data-anim-out="bounceIn" href="/index.htm">
#             <img alt="" src="/images/logo.png"/>
#            </a>
#            <strong data-anim-in="fadeOutUpBig" data-anim-out="bounceIn">
#             <i class="fa fa-home">
#             </i>
#             Homepage
#            </strong>
#           </div>
#           <div class="header-socials">
#            <a href="https://twitter.com/TDLRLicense">
#             <i class="fa fa-twitter">
#             </i>
#            </a>
#            <a href="https://www.facebook.com/TDLRLicense">
#             <i class="fa fa-facebook">
#             </i>
#            </a>
#            <a href="https://www.youtube.com/user/TexasLicensing/videos">
#             <i class="fa fa-youtube">
#             </i>
#            </a>
#           </div>
#          </div>
#          <!-- end header-left -->
#          <div class="header-right">
#           <nav class="main-menu transition-active">
#            <ul class="load-responsive" rel="Main Menu">
#             <li class="has-ot-mega-menu">
#              <a href="/licenses.htm">
#               <span>
#                License Types
#                <i>
#                 Regulated by TDLR
#                </i>
#               </span>
#              </a>
#              <ul class="ot-mega-menu">
#               <li class="ot-dropdown menu-item">
#                <ul class="widget-menu widget">
#                 <li>
#                  <a href="/acr/acr.htm">
#                   Air Conditioning and Refrigeration Contractors
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/ab/ab.htm">
#                   Elimination of Architectural Barriers
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/at/at.htm">
#                   Athletic Trainers
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/auc/auction.htm">
#                   Auctioneers
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/barbers/barbers.htm">
#                   Barbering
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/boilers/blr.htm">
#                   Boiler Safety
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/sports/sports.htm">
#                   Combative Sports
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/ceo/ceo.htm">
#                   Code Enforcement Officers
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/cosmet/cosmet.htm">
#                   Cosmetologists
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/diet/diet.htm">
#                   Dietitians
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/driver/driver.htm">
#                   Driver Education and Safety
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/dtp/dtp.htm">
#                   Dyslexia Therapists and Practicioners
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li class="ot-dropdown menu-item">
#                <ul class="widget-menu widget">
#                 <li>
#                  <a href="/electricians/elec.htm">
#                   Electricians
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/elevator/ele.htm">
#                   Elevator / Escalator Safety
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/legalsvcs/legalsvcs.htm">
#                   For-Profit Legal Services
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/hearing/hearing.htm">
#                   Hearing Instrument Fitters and Dispensers
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/ihb/ihb.htm">
#                   Industrialized Housing and Buildings
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/las/las.htm">
#                   Laser Hair Removal
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/bre/bre.htm">
#                   Licensed Breeders
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/mas/mas.htm">
#                   Massage Therapy
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/midwives/midwives.htm">
#                   Midwives
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/mld/mld.htm">
#                   Mold Assessors and Remediators
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/oep/oep.htm">
#                   Offender Education Providers
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/op/op.htm">
#                   Orthotists and Prosthetists
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/pod/pod.htm">
#                   Podiatry
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/polygraph/polygraph.htm">
#                   Polygraph Examiners
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/peo/peo.htm">
#                   Professional Employer Organizations
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/ptc/ptc.htm">
#                   Property Tax Consultants
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li class="ot-dropdown menu-item">
#                <ul class="widget-menu widget">
#                 <li>
#                  <a href="/taxprof/taxprof.htm">
#                   Property Tax Professionals
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/san/san.htm">
#                   Sanitarians
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/scp/scp.htm">
#                   Service Contract Providers
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/slpa/slpa.htm">
#                   Speech-Language Pathologists and Audiologists
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/towing/towing.htm">
#                   Tow Trucks, Operators and VSFs
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/tnc/tnc.htm">
#                   Transportation Network Services
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/parts/apr.htm">
#                   Used Auto Parts Recyclers
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/wwd/wwd.htm">
#                   Water Well Drillers and Pump Installers
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/weather/weathermod.htm">
#                   Weather Modification
#                  </a>
#                 </li>
#                </ul>
#               </li>
#              </ul>
#             </li>
#             <li>
#              <a href="/services.htm">
#               <span>
#                Online Services
#                <i>
#                 Licenses, Change Your Info, Etc.
#                </i>
#               </span>
#              </a>
#              <ul class="sub-menu">
#               <li>
#                <a href="/services.htm#apply">
#                 <span>
#                  <b>
#                   Apply or Renew a License Online for Programs A-L:
#                  </b>
#                 </span>
#                </a>
#                <ul class="sub-menu">
#                 <li>
#                  <a href="/App_Online/default.asp?LicenseType=ACR">
#                   AC and Refrigeration
#                  </a>
#                 </li>
#                 <li>
#                  <a href="https://vo.licensing.tdlr.texas.gov/">
#                   Athletic Trainers
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/App_Online/default.asp?LicenseType=AUC">
#                   Auctioneers
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/App_Online/default.asp?LicenseType=BAR">
#                   Barbering
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/App_Online/default.asp?LicenseType=COS">
#                   Cosmetologists
#                  </a>
#                 </li>
#                 <li>
#                  <a href="https://vo.licensing.tdlr.texas.gov/">
#                   Dietitians
#                  </a>
#                 </li>
#                 <li>
#                  <a href="https://vo.licensing.tdlr.texas.gov/">
#                   Dyslexia Therapists and Practitioners
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/App_Online/default.asp?LicenseType=ELE">
#                   Electricians
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/App_Online/default.asp?LicenseType=LSC">
#                   For-Profit Legal Svcs
#                  </a>
#                 </li>
#                 <li>
#                  <a href="https://vo.licensing.tdlr.texas.gov/">
#                   Hearing Instrument Fitters and Dispensers
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li>
#                <a href="/services.htm#apply">
#                 <span>
#                  <b>
#                   Apply or Renew a License Online for Programs M-Z:
#                  </b>
#                 </span>
#                </a>
#                <ul class="sub-menu">
#                 <li>
#                  <a href="https://vo.licensing.tdlr.texas.gov/">
#                   Midwives
#                  </a>
#                 </li>
#                 <li>
#                  <a href="https://vo.licensing.tdlr.texas.gov/">
#                   Orthotists and Prosthetists
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/App_Online/default.asp?LicenseType=PTP">
#                   Property Tax Professionals
#                  </a>
#                 </li>
#                 <li>
#                  <a href="https://vo.licensing.tdlr.texas.gov/">
#                   Speech-Language Pathologists and Audiologists
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/App_Online/default.asp?LicenseType=TOW">
#                   Towing/Booting Operator
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/App_Online/default.asp?LicenseType=APR">
#                   Used Auto Parts Recyclers
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/App_Online/default.asp?LicenseType=VSF">
#                   VSF Employee
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li>
#                <a href="#">
#                 <span>
#                  <b>
#                   Other Online Services:
#                  </b>
#                 </span>
#                </a>
#                <ul class="sub-menu">
#                 <li>
#                  <a href="/ContactInfoUpdate/LicenseProgram.aspx">
#                   Change Your Contact Information
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/DuplicateLicense">
#                   Order a Duplicate License
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/App_Online/SearchForDuplicateReceipt.asp">
#                   Duplicate Receipt for Online Renewal
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/App_Online/SearchApplicationDuplicateReceipt.asp">
#                   Duplicate Receipt for Online Application
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/App_Online/BookOrderForm.asp">
#                   Buy Barber / Cosmetology Law and Rule Book
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/App_Online/SearchDuplicateReceiptForBookOrder.asp">
#                   Duplicate Receipt for Law and Rule Book
#                  </a>
#                 </li>
#                </ul>
#               </li>
#              </ul>
#             </li>
#             <li>
#              <a href="/tdlrce.htm">
#               <span>
#                Continuing Education
#               </span>
#              </a>
#              <ul class="sub-menu">
#               <li>
#                <a href="/tdlrce.htm">
#                 <span>
#                  <b>
#                   Tools and Info for CE Providers:
#                  </b>
#                 </span>
#                </a>
#                <ul class="sub-menu">
#                 <li>
#                  <a href="https://www.tdlr.texas.gov/ContinuingEducation/ProviderLogin.aspx">
#                   Post CE Rosters
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/ce/ce.htm">
#                   Information for Continuing Education Providers
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li>
#                <a href="/tdlrce.htm">
#                 <span>
#                  <b>
#                   Continuing Education for Programs A-L:
#                  </b>
#                 </span>
#                </a>
#                <ul class="sub-menu">
#                 <li>
#                  <a href="/ce/ceauc.htm">
#                   Auctioneers
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/ce/ceacr.htm">
#                   ACR Contractors
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/ce/cebooting.htm">
#                   Booting Operators
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/ce/cecos.htm">
#                   Cosmetologists
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/ce/ceelec.htm">
#                   Electricians
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/ce/ceele.htm">
#                   Elevators
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li>
#                <a href="/tdlrce.htm">
#                 <span>
#                  <b>
#                   Continuing Education for Programs M-Z:
#                  </b>
#                 </span>
#                </a>
#                <ul class="sub-menu">
#                 <li>
#                  <a href="/ce/cepol.htm">
#                   Polygraph Examiners
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/ce/ceptc.htm">
#                   Property Tax Consultants
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/ce/ceptp.htm">
#                   Property Tax Professionals
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/ce/ceras.htm">
#                   Registered Accessibility Specialists
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/ce/cetow.htm">
#                   Towing Operators
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/ce/cewwd.htm">
#                   Well Driller and Pump Installers
#                  </a>
#                 </li>
#                </ul>
#               </li>
#              </ul>
#             </li>
#             <li>
#              <a href="/verify.htm">
#               <span>
#                Search / Verify
#                <i>
#                 Licenses or Projects
#                </i>
#               </span>
#              </a>
#              <ul>
#               <li>
#                <a href="/LicenseSearch/">
#                 Search Licensees
#                </a>
#               </li>
#               <li>
#                <a href="/cimsfo/fosearch.asp">
#                 Search for Violations
#                </a>
#               </li>
#               <li>
#                <a href="/TABS/Search">
#                 Search AB Projects
#                </a>
#               </li>
#               <li>
#                <a href="/ElevatorInspection/login.aspx">
#                 Elevator Inspection Reports
#                </a>
#               </li>
#               <li>
#                <a href="/TABS/">
#                 AB Project Registration
#                </a>
#               </li>
#               <li>
#                <a href="/Boilerdata/">
#                 Search Licensed Boilers
#                </a>
#               </li>
#               <li>
#                <a href="/ihb/ihblists.htm">
#                 Search IHB Registrant Lists
#                </a>
#               </li>
#               <li>
#                <a href="/Elevator_SearchApp">
#                 Search Elevators and Related Equipment
#                </a>
#               </li>
#               <li>
#                <a href="/tools_search/">
#                 Search Tow Companies &amp; VSFs
#                </a>
#               </li>
#              </ul>
#             </li>
#             <div class="search-header">
#              <form action="/search/search.asp" method="get">
#               <input name="zoom_query" size="14" type="text"/>
#               <input type="submit" value="Search"/>
#              </form>
#             </div>
#            </ul>
#           </nav>
#           <!-- END main-menu -->
#           <nav class="under-menu">
#            <ul class="load-responsive" rel="Interact with TDLR">
#             <li>
#              <a href="/Complaints/">
#               File A Complaint
#              </a>
#             </li>
#             <li>
#              <a href="https://public.govdelivery.com/accounts/TXDLR/subscriber/new">
#               E-Mail Updates From TDLR
#              </a>
#             </li>
#             <li>
#              <a href="/meetings.htm">
#               Meetings, Commission, Rules and Statute
#              </a>
#             </li>
#             <li>
#              <a href="/employ.htm">
#               Employment
#              </a>
#             </li>
#             <li>
#              <a href="/contact.htm">
#               Contact TDLR
#              </a>
#             </li>
#            </ul>
#           </nav>
#           <!-- END under-menu -->
#          </div>
#          <!-- END header-right -->
#         </div>
#         <!-- END .wrapper -->
#        </header>
#        <section class="content">
#         <div class="wrapper">
#          <div class="main-content">
#           <table align="center" border="0" cellpadding="0" cellspacing="0" style="margin:0 auto;" width="80%">
#            <tbody>
#             <tr>
#              <td>
#               <h1 style="vertical-align: top; text-align: center; width: 100%;">
#                Administrative Orders - Search
#               </h1>
#               <p style="text-align:justify;">
#                This search includes Orders issued by the Commission or Executive Director assessing a sanction,
#                                         an administrative penalty or both for violations of TDLR's program laws and rules.
#                                         This search covers Orders issued during the current and most recent past two fiscal years.
#                                         TDLR's fiscal years begin on September 1st and end on August 31st of each year.
#                                         For information on obtaining copies of Orders not included in this search,
#                                         please submit a written request for the Order(s) to
#                <!--<a href="https://tdlr.govqa.us/WEBAPP/_rs/(S(4f0rowsc13j33zabgexqvihl))/SupportHome.aspx">TDLR Records Center</a>.-->
#                <a href="https://tdlr.govqa.us/WEBAPP/_rs/(S(4f0rowsc13j33zabgexqvihl))/SupportHome.aspx">
#                 TDLR Records Center
#                </a>
#                .
#                <!--<a href="mailto:open.records@tdlr.texas.gov">open.records@tdlr.texas.gov</a>.-->
#               </p>
#               <p style="text-align:center">
#                Submit Questions/Comments to
#                <a href="https://ga.tdlr.texas.gov:1443/form/csgeneralinquiry">
#                 TDLR Online WebForm
#                </a>
#               </p>
#               <form action="fosearch_results.asp" method="post" name="FormPHT" onsubmit="return VerifyPHT(this)">
#                <table style="border: 1px solid #c0c0c0; width: 100%">
#                 <tbody>
#                  <tr>
#                   <td style="padding: 4px;">
#                    <span style="color:#990000;">
#                     <!--Please enter at least one (1) parameter; two (2) if License Program Type is 'Cosmetologists'.-->
#                     Please enter at least one (1) parameter; using multiple parameters is recommended for a faster retrieval.
#                    </span>
#                    <!--<span style="font-size:12pt; font-style:bold; color:#330099">Final Orders - (Note: The earliest available Order Date is 7/28/2022.)</span>-->
#                   </td>
#                  </tr>
#                  <tr>
#                   <td height="18" style="padding: 4px; background: #dedede;">
#                    <label for="pht_status">
#                     Search by License Program Type
#                    </label>
#                   </td>
#                  </tr>
#                  <tr>
#                   <td style="padding: 4px;">
#                    <select class="mousebox" id="pht_status" name="pht_status" size="1" style="height: 22px" tabindex="1">
#                     <option selected="" value="-1">
#                      Choose One (Optional)
#                     </option>
#                     <option value="ACR">
#                      Air Conditioning Contractors and Technicians
#                     </option>
#                     <option value="EAB">
#                      Architectural Barriers
#                     </option>
#                     <option value="ATH">
#                      Athletic Trainers
#                     </option>
#                     <option value="AUC">
#                      Auctioneers
#                     </option>
#                     <option value="BAR">
#                      Barbers
#                     </option>
#                     <option value="BLR">
#                      Boilers
#                     </option>
#                     <option value="CEO">
#                      Code Enforcement Officers
#                     </option>
#                     <option value="BOX">
#                      Combative Sports
#                     </option>
#                     <option value="COS">
#                      Cosmetologists
#                     </option>
#                     <option value="DTN">
#                      Dietitians
#                     </option>
#                     <option value="DES">
#                      Driver Education and Safety
#                     </option>
#                     <option value="DYS">
#                      Dyslexia Therapists and Practicioners
#                     </option>
#                     <option value="ELC">
#                      Electricians
#                     </option>
#                     <option value="ELE">
#                      Elevators, Escalators
#                     </option>
#                     <option value="EL1">
#                      Elevator Inspectors
#                     </option>
#                     <option value="EL2">
#                      Elevator Contractors
#                     </option>
#                     <option value="LSC">
#                      For Profit Legal Service Contracts
#                     </option>
#                     <option value="HFD">
#                      Hearing Instrument Fitters and Dispensers
#                     </option>
#                     <option value="IHB">
#                      Industrialized Housing and Buildings
#                     </option>
#                     <option value="LAS">
#                      Laser Hair Removal
#                     </option>
#                     <option value="BRE">
#                      Licensed Breeders
#                     </option>
#                     <option value="MAS">
#                      Massage Therapy
#                     </option>
#                     <option value="MID">
#                      Midwives
#                     </option>
#                     <option value="MLD">
#                      Mold Assessors and Remediators
#                     </option>
#                     <option value="FMQ">
#                      Motor Fuel Metering and Quality
#                     </option>
#                     <option value="OEP">
#                      Offender Education Providers
#                     </option>
#                     <option value="OPS">
#                      Orthotists and Prosthetists
#                     </option>
#                     <option value="POD">
#                      Podiatry
#                     </option>
#                     <option value="POL">
#                      Polygraph Examiners
#                     </option>
#                     <option value="SLS">
#                      Professional Employer Organization
#                     </option>
#                     <option value="PTC">
#                      Property Tax Consultants
#                     </option>
#                     <option value="PTP">
#                      Property Tax Professionals
#                     </option>
#                     <option value="RAS">
#                      Registered Accessibility Specialist
#                     </option>
#                     <option value="SAN">
#                      Sanitarians
#                     </option>
#                     <option value="SCP">
#                      Service Contract Providers
#                     </option>
#                     <option value="SPA">
#                      Speech-Language Pathologists and Audiologists
#                     </option>
#                     <option value="TNC">
#                      Transportation Network Companies
#                     </option>
#                     <option value="TOW">
#                      Tow Truck Companies
#                     </option>
#                     <option value="APR">
#                      Used Automotive Parts Recyclers
#                     </option>
#                     <option value="VSF">
#                      Vehicle Storage Facilities
#                     </option>
#                     <option value="WWD">
#                      Water Well Drillers, Pump Installers
#                     </option>
#                     <option value="WXM">
#                      Weather Modification
#                     </option>
#                    </select>
#                   </td>
#                  </tr>
#                  <tr>
#                   <td style="padding: 4px; background: #dedede;">
#                    <label for="pht_lic">
#                     Search by License #
#                    </label>
#                   </td>
#                  </tr>
#                  <tr>
#                   <td height="22" style="padding: 4px;">
#                    <p class="mousebox">
#                     <input id="pht_lic" maxlength="14" name="pht_lic" size="14" style="WIDTH: 135px; HEIGHT: 22px" tabindex="2"/>
#                     contains
#                    </p>
#                   </td>
#                  </tr>
#                  <tr>
#                   <td height="18" style="padding: 4px; background: #dedede;">
#                    <label for="pht_lnm">
#                     Search by Last Name
#                    </label>
#                   </td>
#                  </tr>
#                  <tr>
#                   <td height="22" style="padding: 4px;">
#                    <p class="mousebox">
#                     <input id="pht_lnm" maxlength="20" name="pht_lnm" size="20" style="height: 22px" tabindex="3"/>
#                     begins with
#                    </p>
#                   </td>
#                  </tr>
#                  <tr>
#                   <td height="18" style="padding: 4px; background: #dedede;">
#                    <label for="pht_fnm">
#                     Search by First Name
#                    </label>
#                   </td>
#                  </tr>
#                  <tr>
#                   <td height="22" style="padding: 4px;">
#                    <p class="mousebox">
#                     <input id="pht_fnm" maxlength="15" name="pht_fnm" size="20" style="height: 22px" tabindex="4"/>
#                     begins with
#                    </p>
#                   </td>
#                  </tr>
#                  <tr>
#                   <td colspan="2" height="18" style="padding: 4px; background: #dedede;">
#                    <label for="pht_oth_name">
#                     Search by Company Name
#                    </label>
#                   </td>
#                  </tr>
#                  <tr>
#                   <td height="22" style="padding: 4px;">
#                    <p class="mousebox">
#                     <input id="pht_oth_name" maxlength="20" name="pht_oth_name" size="20" style="height: 22px" tabindex="5"/>
#                     begins with
#                    </p>
#                   </td>
#                  </tr>
#                  <tr>
#                   <td height="18" style="padding: 4px; background: #dedede;">
#                    <label for="phy_city">
#                     Search by City
#                    </label>
#                   </td>
#                  </tr>
#                  <tr>
#                   <td height="22" style="padding: 4px;">
#                    <p class="mousebox">
#                     <select class="mousebox" id="phy_city" name="phy_city" size="1" style="height: 22px" tabindex="8">
#                      <option selected="" value="-1">
#                       Choose a City (Optional)
#                      </option>
#                      <option value="ABBOTT              ">
#                       Abbott
#                      </option>
#                      <option value="ABERNATHY           ">
#                       Abernathy
#                      </option>
#                      <option value="ABILENE             ">
#                       Abilene
#                      </option>
#                      <option value="ACE                 ">
#                       Ace
#                      </option>
#                      <option value="ACKERLY             ">
#                       Ackerly
#                      </option>
#                      <option value="ACTON               ">
#                       Acton
#                      </option>
#                      <option value="ADAMSVILLE          ">
#                       Adamsville
#                      </option>
#                      <option value="ADDISON             ">
#                       Addison
#                      </option>
#                      <option value="ADELL               ">
#                       Adell
#                      </option>
#                      <option value="ADKINS              ">
#                       Adkins
#                      </option>
#                      <option value="ADRIAN              ">
#                       Adrian
#                      </option>
#                      <option value="AFTON               ">
#                       Afton
#                      </option>
#                      <option value="AGNUS               ">
#                       Agnus
#                      </option>
#                      <option value="AGUA DULCE          ">
#                       Agua Dulce
#                      </option>
#                      <option value="AGUILARES           ">
#                       Aguilares
#                      </option>
#                      <option value="AIKEN               ">
#                       Aiken
#                      </option>
#                      <option value="ALAMO               ">
#                       Alamo
#                      </option>
#                      <option value="ALAMO HEIGHTS       ">
#                       Alamo Heights
#                      </option>
#                      <option value="ALANREED            ">
#                       Alanreed
#                      </option>
#                      <option value="ALBA                ">
#                       Alba
#                      </option>
#                      <option value="ALBANY              ">
#                       Albany
#                      </option>
#                      <option value="ALDINE              ">
#                       Aldine
#                      </option>
#                      <option value="ALEDO               ">
#                       Aledo
#                      </option>
#                      <option value="ALGOA               ">
#                       Algoa
#                      </option>
#                      <option value="ALICE               ">
#                       Alice
#                      </option>
#                      <option value="ALIEF               ">
#                       Alief
#                      </option>
#                      <option value="ALLEN               ">
#                       Allen
#                      </option>
#                      <option value="ALLEYTON            ">
#                       Alleyton
#                      </option>
#                      <option value="ALLISON             ">
#                       Allison
#                      </option>
#                      <option value="ALMA                ">
#                       Alma
#                      </option>
#                      <option value="ALPINE              ">
#                       Alpine
#                      </option>
#                      <option value="ALTA LOMA           ">
#                       Alta Loma
#                      </option>
#                      <option value="ALTAIR              ">
#                       Altair
#                      </option>
#                      <option value="ALTO                ">
#                       Alto
#                      </option>
#                      <option value="ALTOGA              ">
#                       Altoga
#                      </option>
#                      <option value="ALTON               ">
#                       Alton
#                      </option>
#                      <option value="ALVARADO            ">
#                       Alvarado
#                      </option>
#                      <option value="ALVAREDO            ">
#                       Alvaredo
#                      </option>
#                      <option value="ALVIN               ">
#                       Alvin
#                      </option>
#                      <option value="ALVORD              ">
#                       Alvord
#                      </option>
#                      <option value="AMARILLO            ">
#                       Amarillo
#                      </option>
#                      <option value="AMES                ">
#                       Ames
#                      </option>
#                      <option value="AMHERST             ">
#                       Amherst
#                      </option>
#                      <option value="ANAHUAC             ">
#                       Anahuac
#                      </option>
#                      <option value="ANDERSON            ">
#                       Anderson
#                      </option>
#                      <option value="ANDICE              ">
#                       Andice
#                      </option>
#                      <option value="ANDREWS             ">
#                       Andrews
#                      </option>
#                      <option value="ANGLETON            ">
#                       Angleton
#                      </option>
#                      <option value="ANNA                ">
#                       Anna
#                      </option>
#                      <option value="ANNETTA             ">
#                       Annetta
#                      </option>
#                      <option value="ANNONA              ">
#                       Annona
#                      </option>
#                      <option value="ANSON               ">
#                       Anson
#                      </option>
#                      <option value="ANTHONY             ">
#                       Anthony
#                      </option>
#                      <option value="ANTON               ">
#                       Anton
#                      </option>
#                      <option value="APPLE SPRINGS       ">
#                       Apple Springs
#                      </option>
#                      <option value="AQUILLA             ">
#                       Aquilla
#                      </option>
#                      <option value="ARANSAS PASS        ">
#                       Aransas Pass
#                      </option>
#                      <option value="ARCADIA             ">
#                       Arcadia
#                      </option>
#                      <option value="ARCHER CITY         ">
#                       Archer City
#                      </option>
#                      <option value="ARCOLA              ">
#                       Arcola
#                      </option>
#                      <option value="ARGYLE              ">
#                       Argyle
#                      </option>
#                      <option value="ARLINGTON           ">
#                       Arlington
#                      </option>
#                      <option value="ARMSTRONG           ">
#                       Armstrong
#                      </option>
#                      <option value="ARP                 ">
#                       Arp
#                      </option>
#                      <option value="ARROYO              ">
#                       Arroyo
#                      </option>
#                      <option value="ART                 ">
#                       Art
#                      </option>
#                      <option value="ARTESIA WELLS       ">
#                       Artesia Wells
#                      </option>
#                      <option value="ARTHUR CITY         ">
#                       Arthur City
#                      </option>
#                      <option value="ASHERTON            ">
#                       Asherton
#                      </option>
#                      <option value="ASPERMONT           ">
#                       Aspermont
#                      </option>
#                      <option value="ATASCOCITA          ">
#                       Atascocita
#                      </option>
#                      <option value="ATASCOSA            ">
#                       Atascosa
#                      </option>
#                      <option value="ATHENS              ">
#                       Athens
#                      </option>
#                      <option value="ATLANTA             ">
#                       Atlanta
#                      </option>
#                      <option value="AUBREY              ">
#                       Aubrey
#                      </option>
#                      <option value="AURORA              ">
#                       Aurora
#                      </option>
#                      <option value="AUSTIN              ">
#                       Austin
#                      </option>
#                      <option value="AUSTWELL            ">
#                       Austwell
#                      </option>
#                      <option value="AVALON              ">
#                       Avalon
#                      </option>
#                      <option value="AVERY               ">
#                       Avery
#                      </option>
#                      <option value="AVINGER             ">
#                       Avinger
#                      </option>
#                      <option value="AVOCA               ">
#                       Avoca
#                      </option>
#                      <option value="AXTELL              ">
#                       Axtell
#                      </option>
#                      <option value="AZLE                ">
#                       Azle
#                      </option>
#                      <option value="BACLIFF             ">
#                       Bacliff
#                      </option>
#                      <option value="BAGWELL             ">
#                       Bagwell
#                      </option>
#                      <option value="BAILEY              ">
#                       Bailey
#                      </option>
#                      <option value="BAILEYS PRAIRIE     ">
#                       Baileys Prairie
#                      </option>
#                      <option value="BAIRD               ">
#                       Baird
#                      </option>
#                      <option value="BALCH SPRINGS       ">
#                       Balch Springs
#                      </option>
#                      <option value="BALCONES HEIGHTS    ">
#                       Balcones Heights
#                      </option>
#                      <option value="BALLINGER           ">
#                       Ballinger
#                      </option>
#                      <option value="BALMORHEA           ">
#                       Balmorhea
#                      </option>
#                      <option value="BANDERA             ">
#                       Bandera
#                      </option>
#                      <option value="BANGS               ">
#                       Bangs
#                      </option>
#                      <option value="BANQUETE            ">
#                       Banquete
#                      </option>
#                      <option value="BARDWELL            ">
#                       Bardwell
#                      </option>
#                      <option value="BARKER              ">
#                       Barker
#                      </option>
#                      <option value="BARKSDALE           ">
#                       Barksdale
#                      </option>
#                      <option value="BARNHART            ">
#                       Barnhart
#                      </option>
#                      <option value="BARRY               ">
#                       Barry
#                      </option>
#                      <option value="BARSTOW             ">
#                       Barstow
#                      </option>
#                      <option value="BARTLETT            ">
#                       Bartlett
#                      </option>
#                      <option value="BARTONVILLE         ">
#                       Bartonville
#                      </option>
#                      <option value="BASTROP             ">
#                       Bastrop
#                      </option>
#                      <option value="BATESVILLE          ">
#                       Batesville
#                      </option>
#                      <option value="BATSON              ">
#                       Batson
#                      </option>
#                      <option value="BAY CITY            ">
#                       Bay City
#                      </option>
#                      <option value="BAYOU VISTA         ">
#                       Bayou Vista
#                      </option>
#                      <option value="BAYSIDE             ">
#                       Bayside
#                      </option>
#                      <option value="BAYTOWN             ">
#                       Baytown
#                      </option>
#                      <option value="BAYVIEW             ">
#                       Bayview
#                      </option>
#                      <option value="BEACH CITY          ">
#                       Beach City
#                      </option>
#                      <option value="BEASLEY             ">
#                       Beasley
#                      </option>
#                      <option value="BEAUMONT            ">
#                       Beaumont
#                      </option>
#                      <option value="BEBE                ">
#                       Bebe
#                      </option>
#                      <option value="BECKVILLE           ">
#                       Beckville
#                      </option>
#                      <option value="BEDFORD             ">
#                       Bedford
#                      </option>
#                      <option value="BEDIAS              ">
#                       Bedias
#                      </option>
#                      <option value="BEE CAVE            ">
#                       Bee Cave
#                      </option>
#                      <option value="BEEVILLE            ">
#                       Beeville
#                      </option>
#                      <option value="BELDING             ">
#                       Belding
#                      </option>
# ...
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="widget">
#           <div>
#            <ul>
#             <li>
#              <a href="/compact.htm">
#               Compact with Texans
#              </a>
#             </li>
#             <li>
#              <a href="https://www.texas.gov/">
#               Texas.gov
#              </a>
#             </li>
#             <li>
#              <a href="https://www.tsl.texas.gov/trail/index.html">
#               Statewide Search
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="widget">
#           <div>
#            <ul>
#             <li>
#              <a href="https://governor.state.tx.us/homeland">
#               Texas Homeland Security
#              </a>
#             </li>
#             <li>
#              <a href="https://www.texastransparency.org/">
#               Texas Transparency
#              </a>
#             </li>
#             <li>
#              <a href="https://veterans.portal.texas.gov/en/Pages/default.aspx">
#               Texas Veterans Portal
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </div>
#        <!-- END .wrapper -->
#       </footer>
#      </div>
#      <!-- END .boxed -->
#      <script src="/jscript/jquery-latest.min.js" type="text/javascript">
#      </script>
#      <script src="/jscript/snap.svg-min.js" type="text/javascript">
#      </script>
#      <script src="/jscript/theme-scripts.js" type="text/javascript">
#      </script>
#      <script src="/jscript/lightbox.js" type="text/javascript">
#      </script>
#      <script src="/jscript/SmoothScroll.min.js" type="text/javascript">
#      </script>
#      <script src="/jscript/iscroll.js" type="text/javascript">
#      </script>
#      <script src="/jscript/modernizr.custom.50878.js" type="text/javascript">
#      </script>
#      <script src="/jscript/dat-menu.js" type="text/javascript">
#      </script>
#      <div style="clear: both;">
#      </div>
#     </div>
#    </div>
#    <nav class="dat-menu-list dat-submenu" style="touch-action: none;">
#     <ul id="dat-menu-list-inner" style="transform: translate(0px, 0px) translateZ(0px);">
#      <li class="dat-menu-header">
#       <span>
#        Main Menu
#       </span>
#      </li>
#      <li class="has-ot-mega-menu dat-has-sub">
#       <a href="/licenses.htm">
#        <span>
#         License Types
#         <i>
#          Regulated by TDLR
#         </i>
#        </span>
#       </a>
#       <ul class="ot-mega-menu">
#        <li class="ot-dropdown menu-item dat-has-sub">
#         <ul class="widget-menu widget">
#          <li>
#           <a href="/acr/acr.htm">
#            Air Conditioning and Refrigeration Contractors
#           </a>
#          </li>
#          <li>
#           <a href="/ab/ab.htm">
#            Elimination of Architectural Barriers
#           </a>
#          </li>
#          <li>
#           <a href="/at/at.htm">
#            Athletic Trainers
#           </a>
#          </li>
#          <li>
#           <a href="/auc/auction.htm">
#            Auctioneers
#           </a>
#          </li>
#          <li>
#           <a href="/barbers/barbers.htm">
#            Barbering
#           </a>
#          </li>
#          <li>
#           <a href="/boilers/blr.htm">
#            Boiler Safety
#           </a>
#          </li>
#          <li>
#           <a href="/sports/sports.htm">
#            Combative Sports
#           </a>
#          </li>
#          <li>
#           <a href="/ceo/ceo.htm">
#            Code Enforcement Officers
#           </a>
#          </li>
#          <li>
#           <a href="/cosmet/cosmet.htm">
#            Cosmetologists
#           </a>
#          </li>
#          <li>
#           <a href="/diet/diet.htm">
#            Dietitians
#           </a>
#          </li>
#          <li>
#           <a href="/driver/driver.htm">
#            Driver Education and Safety
#           </a>
#          </li>
#          <li>
#           <a href="/dtp/dtp.htm">
#            Dyslexia Therapists and Practicioners
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="ot-dropdown menu-item dat-has-sub">
#         <ul class="widget-menu widget">
#          <li>
#           <a href="/electricians/elec.htm">
#            Electricians
#           </a>
#          </li>
#          <li>
#           <a href="/elevator/ele.htm">
#            Elevator / Escalator Safety
#           </a>
#          </li>
#          <li>
#           <a href="/legalsvcs/legalsvcs.htm">
#            For-Profit Legal Services
#           </a>
#          </li>
#          <li>
#           <a href="/hearing/hearing.htm">
#            Hearing Instrument Fitters and Dispensers
#           </a>
#          </li>
#          <li>
#           <a href="/ihb/ihb.htm">
#            Industrialized Housing and Buildings
#           </a>
#          </li>
#          <li>
#           <a href="/las/las.htm">
#            Laser Hair Removal
#           </a>
#          </li>
#          <li>
#           <a href="/bre/bre.htm">
#            Licensed Breeders
#           </a>
#          </li>
#          <li>
#           <a href="/mas/mas.htm">
#            Massage Therapy
#           </a>
#          </li>
#          <li>
#           <a href="/midwives/midwives.htm">
#            Midwives
#           </a>
#          </li>
#          <li>
#           <a href="/mld/mld.htm">
#            Mold Assessors and Remediators
#           </a>
#          </li>
#          <li>
#           <a href="/oep/oep.htm">
#            Offender Education Providers
#           </a>
#          </li>
#          <li>
#           <a href="/op/op.htm">
#            Orthotists and Prosthetists
#           </a>
#          </li>
#          <li>
#           <a href="/pod/pod.htm">
#            Podiatry
#           </a>
#          </li>
#          <li>
#           <a href="/polygraph/polygraph.htm">
#            Polygraph Examiners
#           </a>
#          </li>
#          <li>
#           <a href="/peo/peo.htm">
#            Professional Employer Organizations
#           </a>
#          </li>
#          <li>
#           <a href="/ptc/ptc.htm">
#            Property Tax Consultants
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="ot-dropdown menu-item dat-has-sub">
#         <ul class="widget-menu widget">
#          <li>
#           <a href="/taxprof/taxprof.htm">
#            Property Tax Professionals
#           </a>
#          </li>
#          <li>
#           <a href="/san/san.htm">
#            Sanitarians
#           </a>
#          </li>
#          <li>
#           <a href="/scp/scp.htm">
#            Service Contract Providers
#           </a>
#          </li>
#          <li>
#           <a href="/slpa/slpa.htm">
#            Speech-Language Pathologists and Audiologists
#           </a>
#          </li>
#          <li>
#           <a href="/towing/towing.htm">
#            Tow Trucks, Operators and VSFs
#           </a>
#          </li>
#          <li>
#           <a href="/tnc/tnc.htm">
#            Transportation Network Services
#           </a>
#          </li>
#          <li>
#           <a href="/parts/apr.htm">
#            Used Auto Parts Recyclers
#           </a>
#          </li>
#          <li>
#           <a href="/wwd/wwd.htm">
#            Water Well Drillers and Pump Installers
#           </a>
#          </li>
#          <li>
#           <a href="/weather/weathermod.htm">
#            Weather Modification
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#      </li>
#      <li class="dat-has-sub">
#       <a href="/services.htm">
#        <span>
#         Online Services
#         <i>
#          Licenses, Change Your Info, Etc.
#         </i>
#        </span>
#       </a>
#       <ul class="sub-menu">
#        <li class="dat-has-sub">
#         <a href="/services.htm#apply">
#          <span>
#           <b>
#            Apply or Renew a License Online for Programs A-L:
#           </b>
#          </span>
#         </a>
#         <ul class="sub-menu">
#          <li>
#           <a href="/App_Online/default.asp?LicenseType=ACR">
#            AC and Refrigeration
#           </a>
#          </li>
#          <li>
#           <a href="https://vo.licensing.tdlr.texas.gov/">
#            Athletic Trainers
#           </a>
#          </li>
#          <li>
#           <a href="/App_Online/default.asp?LicenseType=AUC">
#            Auctioneers
#           </a>
#          </li>
#          <li>
#           <a href="/App_Online/default.asp?LicenseType=BAR">
#            Barbering
#           </a>
#          </li>
#          <li>
#           <a href="/App_Online/default.asp?LicenseType=COS">
#            Cosmetologists
#           </a>
#          </li>
#          <li>
#           <a href="https://vo.licensing.tdlr.texas.gov/">
#            Dietitians
#           </a>
#          </li>
#          <li>
#           <a href="https://vo.licensing.tdlr.texas.gov/">
#            Dyslexia Therapists and Practitioners
#           </a>
#          </li>
#          <li>
#           <a href="/App_Online/default.asp?LicenseType=ELE">
#            Electricians
#           </a>
#          </li>
#          <li>
#           <a href="/App_Online/default.asp?LicenseType=LSC">
#            For-Profit Legal Svcs
#           </a>
#          </li>
#          <li>
#           <a href="https://vo.licensing.tdlr.texas.gov/">
#            Hearing Instrument Fitters and Dispensers
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="dat-has-sub">
#         <a href="/services.htm#apply">
#          <span>
#           <b>
#            Apply or Renew a License Online for Programs M-Z:
#           </b>
#          </span>
#         </a>
#         <ul class="sub-menu">
#          <li>
#           <a href="https://vo.licensing.tdlr.texas.gov/">
#            Midwives
#           </a>
#          </li>
#          <li>
#           <a href="https://vo.licensing.tdlr.texas.gov/">
#            Orthotists and Prosthetists
#           </a>
#          </li>
#          <li>
#           <a href="/App_Online/default.asp?LicenseType=PTP">
#            Property Tax Professionals
#           </a>
#          </li>
#          <li>
#           <a href="https://vo.licensing.tdlr.texas.gov/">
#            Speech-Language Pathologists and Audiologists
#           </a>
#          </li>
#          <li>
#           <a href="/App_Online/default.asp?LicenseType=TOW">
#            Towing/Booting Operator
#           </a>
#          </li>
#          <li>
#           <a href="/App_Online/default.asp?LicenseType=APR">
#            Used Auto Parts Recyclers
#           </a>
#          </li>
#          <li>
#           <a href="/App_Online/default.asp?LicenseType=VSF">
#            VSF Employee
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="dat-has-sub">
#         <a href="#">
#          <span>
#           <b>
#            Other Online Services:
#           </b>
#          </span>
#         </a>
#         <ul class="sub-menu">
#          <li>
#           <a href="/ContactInfoUpdate/LicenseProgram.aspx">
#            Change Your Contact Information
#           </a>
#          </li>
#          <li>
#           <a href="/DuplicateLicense">
#            Order a Duplicate License
#           </a>
#          </li>
#          <li>
#           <a href="/App_Online/SearchForDuplicateReceipt.asp">
#            Duplicate Receipt for Online Renewal
#           </a>
#          </li>
#          <li>
#           <a href="/App_Online/SearchApplicationDuplicateReceipt.asp">
#            Duplicate Receipt for Online Application
#           </a>
#          </li>
#          <li>
#           <a href="/App_Online/BookOrderForm.asp">
#            Buy Barber / Cosmetology Law and Rule Book
#           </a>
#          </li>
#          <li>
#           <a href="/App_Online/SearchDuplicateReceiptForBookOrder.asp">
#            Duplicate Receipt for Law and Rule Book
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#      </li>
#      <li class="dat-has-sub">
#       <a href="/tdlrce.htm">
#        <span>
#         Continuing Education
#        </span>
#       </a>
#       <ul class="sub-menu">
#        <li class="dat-has-sub">
#         <a href="/tdlrce.htm">
#          <span>
#           <b>
#            Tools and Info for CE Providers:
#           </b>
#          </span>
#         </a>
#         <ul class="sub-menu">
#          <li>
#           <a href="https://www.tdlr.texas.gov/ContinuingEducation/ProviderLogin.aspx">
#            Post CE Rosters
#           </a>
#          </li>
#          <li>
#           <a href="/ce/ce.htm">
#            Information for Continuing Education Providers
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="dat-has-sub">
#         <a href="/tdlrce.htm">
#          <span>
#           <b>
#            Continuing Education for Programs A-L:
#           </b>
#          </span>
#         </a>
#         <ul class="sub-menu">
#          <li>
#           <a href="/ce/ceauc.htm">
#            Auctioneers
#           </a>
#          </li>
#          <li>
#           <a href="/ce/ceacr.htm">
#            ACR Contractors
#           </a>
#          </li>
#          <li>
#           <a href="/ce/cebooting.htm">
#            Booting Operators
#           </a>
#          </li>
#          <li>
#           <a href="/ce/cecos.htm">
#            Cosmetologists
#           </a>
#          </li>
#          <li>
#           <a href="/ce/ceelec.htm">
#            Electricians
#           </a>
#          </li>
#          <li>
#           <a href="/ce/ceele.htm">
#            Elevators
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="dat-has-sub">
#         <a href="/tdlrce.htm">
#          <span>
#           <b>
#            Continuing Education for Programs M-Z:
#           </b>
#          </span>
#         </a>
#         <ul class="sub-menu">
#          <li>
#           <a href="/ce/cepol.htm">
#            Polygraph Examiners
#           </a>
#          </li>
#          <li>
#           <a href="/ce/ceptc.htm">
#            Property Tax Consultants
#           </a>
#          </li>
#          <li>
#           <a href="/ce/ceptp.htm">
#            Property Tax Professionals
#           </a>
#          </li>
#          <li>
#           <a href="/ce/ceras.htm">
#            Registered Accessibility Specialists
#           </a>
#          </li>
#          <li>
#           <a href="/ce/cetow.htm">
#            Towing Operators
#           </a>
#          </li>
#          <li>
#           <a href="/ce/cewwd.htm">
#            Well Driller and Pump Installers
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#      </li>
#      <li class="dat-has-sub">
#       <a href="/verify.htm">
#        <span>
#         Search / Verify
#         <i>
#          Licenses or Projects
#         </i>
#        </span>
#       </a>
#       <ul>
#        <li>
#         <a href="/LicenseSearch/">
#          Search Licensees
#         </a>
#        </li>
#        <li>
#         <a href="/cimsfo/fosearch.asp">
#          Search for Violations
#         </a>
#        </li>
#        <li>
#         <a href="/TABS/Search">
#          Search AB Projects
#         </a>
#        </li>
#        <li>
#         <a href="/ElevatorInspection/login.aspx">
#          Elevator Inspection Reports
#         </a>
#        </li>
#        <li>
#         <a href="/TABS/">
#          AB Project Registration
#         </a>
#        </li>
#        <li>
#         <a href="/Boilerdata/">
#          Search Licensed Boilers
#         </a>
#        </li>
#        <li>
#         <a href="/ihb/ihblists.htm">
#          Search IHB Registrant Lists
#         </a>
#        </li>
#        <li>
#         <a href="/Elevator_SearchApp">
#          Search Elevators and Related Equipment
#         </a>
#        </li>
#        <li>
#         <a href="/tools_search/">
#          Search Tow Companies &amp; VSFs
#         </a>
#        </li>
#       </ul>
#      </li>
#      <div class="search-header">
#       <form action="/search/search.asp" method="get">
#        <input name="zoom_query" size="14" type="text"/>
#        <input type="submit" value="Search"/>
#       </form>
#      </div>
#      <li class="dat-menu-header">
#       <span>
#        Interact with TDLR
#       </span>
#      </li>
#      <li>
#       <a href="/Complaints/">
#        File A Complaint
#       </a>
#      </li>
#      <li>
#       <a href="https://public.govdelivery.com/accounts/TXDLR/subscriber/new">
#        E-Mail Updates From TDLR
#       </a>
#      </li>
#      <li>
#       <a href="/meetings.htm">
#        Meetings, Commission, Rules and Statute
#       </a>
#      </li>
#      <li>
#       <a href="/employ.htm">
#        Employment
#       </a>
#      </li>
#      <li>
#       <a href="/contact.htm">
#        Contact TDLR
#       </a>
#      </li>
#     </ul>
#    </nav>
#   </div>
#  </body>
# </html>

# %% [markdown]
# ### Grab the rows, loop through each result and print the entire row
#
# It's probably too many rows to do all at once: once you have a list, use `[:10]` to only show the first ten! For example, if you saved the table rows into `results` you might do something like this:
#
# ```python
# for result in results[:10]:
#     print("------")
#     print(result)
# ```
#
# Although you'd want to print out the text from the row (I give example output below).

# %% [markdown]
# The result should look something like this:
#
# ```
# Name and Location Order Basis for Order
# NGUYEN, THANH
# City: FRISCO
# County: COLLIN
# Zip Code: 75034
#
#
# License #: 790672
#
# Complaint # COS20210004784 Date: 11/16/2021
#
# Respondent is assessed an administrative penalty in the amount of $1,875. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging 2 violations; Respondent operated a cosmetology salon without the appropriate license.
# NGUYEN, LONG D
# City: SAN SABA
# County: SAN SABA
# Zip Code: 76877
# ```

# %% [markdown]
# ### Loop through each result and print each person's name
#
# You'll probably get an error because the first one doesn't have a name. How do you make that not happen?! If you want to ignore an error, you use code like this:
#
# ```python
# try:
#    # try to do something
# except:
#    print("It didn't work')
# ```
#
# It should help you out. If you don't want to print anything when there's an error, you can type `pass` instead of the `print` statement.
#
# **Why doesn't the first one have a name?**
#
# Output should look like this:
#
# ```
# Doesn't have a name
# NGUYEN, THANH
# NGUYEN, LONG D
# NGUYEN, LUCIE HUONG
# NGUYEN, CHINH
# NGUYEN, JIMMY
# ```
#
# * *Tip: The name has a class you can use. The class name is reused in a lot of places, but because it's the first one you don't have to worry about that!*
# * *Tip: Instead of searching across the entire page – like `doc.select_one` – you should be doing your searching just inside of each **row** (I used this technique in the beginning of class with BeautifulSoup when we were scraping the books page)*

# %% [markdown]
# ## Loop through each result, printing each violation description ("Basis for order")
#
# Your results should look something like:
#
# ```
# Doesn't have a violation
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging 2 violations; Respondent operated a cosmetology salon without the appropriate license.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client.
# ...
# ```
#
# > - *Tip: You'll get an error even if you're ALMOST right - which row is causing the problem?*
# > - *Tip: Or I guess you could just skip the one with the problem using try/except...*

# %% [markdown]
# ## Loop through each result, printing the complaint number
#
# Output should look similar to this:
#
# ```
# Doesn't have a complaint number
# COS20210004784
# COS20210009745
# COS20210011484
# ...
# ```
#
# - *Tip: Think about the order of the elements. Can you count from the opposite direction than you normally do?*

# %% [markdown]
# ## Saving the results
#
# ### Loop through each result to create a list of dictionaries
#
# Each dictionary must contain
#
# - Person's name
# - Violation description
# - Violation number
# - License Numbers
# - Zip Code
# - County
# - City
#
# Create a new dictionary for each result (except the header).
#
# Based on what you print out, the output might look something like:
#
# ```
# This row is broken: Name and Location Order Basis for Order
# {'name': 'NGUYEN, THANH', 'city': 'FRISCO', 'county': 'COLLIN', 'zip_code': '75034', 'complaint_no': 'COS20210004784', 'license_numbers': '790672', 'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging 2 violations; Respondent operated a cosmetology salon without the appropriate license.'}
# {'name': 'NGUYEN, LONG D', 'city': 'SAN SABA', 'county': 'SAN SABA', 'zip_code': '76877', 'complaint_no': 'COS20210009745', 'license_numbers': '760420, 1620583', 'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client.'}
# ```
#
# > _**Tip:** Depending on how you do this, you might want to figure out how to search for "next siblings" or "following siblings"_

# %% [markdown]
# ### Save that to a CSV named `output.csv`
#
# The dataframe should look something like...
#
# |index|name|city|county|zip_code|complaint_no|license_numbers|complaint|
# |---|---|---|---|---|---|---|---|
# |0|NGUYEN, THANH|FRISCO|COLLIN|75034|COS20210004784|790672|Respondent failed to clean and sanitize whirlp...|
# |1|NGUYEN, LONG D|SAN SABA|SAN SABA|76877|COS20210009745|760420, 1620583|Respondent failed to keep a record of the date...|
#
#
# - *Tip: If you send a list of dictionaries to `pd.DataFrame(...)`, it will create a dataframe out of that list!*

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.
